# %%
show_expected_result = False
show_hints = False

import numpy as np

def anomaly(allyears):
    # Your code goes here.
    rList = []
    refArr = allyears[65:76, :]
    avgHigh = np.mean(refArr['TMAX'], axis = 0)
    avgLow = np.mean(refArr['TMIN'], axis = 0)
    avgTemp = (avgHigh+avgLow)

    
    
    return np.array(rList, dtype=np.float64)
